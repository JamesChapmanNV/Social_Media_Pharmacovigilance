# %% [markdown]
# # Get Erowid data
# <br>
# James Chapman<br>
# CIS 830 Advanced Topics in AI – Term Project<br>
# Kansas State University<br><br>
#
# This notebook collects URLs from Erowid's [Main Chart of substances](https://www.erowid.org/general/big_chart.shtml).<br>
#
# This will be used for RAG (the text/HTML/content from these URLs will be ingested by langchain)<br>
#
#
# #### Main Chart of substances <br>
#
# Each substance has a category and name (often slightly different than other websites).<br>
#
# columns (each with a URL)
# - MainPage
# - Basics
# - Images
# - Law
# - Dose
# - Experiences
# - FAQ
# - Effects
# - Chemistry
# - Testing
# - Health
# - History
# - Spiritual
# - Cultivation
# - Books
# - Journals
# - Writings
# - Media

# %% [markdown]
# ### Saves CSV with the following columns (for each URL)
#
# - drug
# - substance
# - category
# - erowid_column
# - url

# %%
import requests
import pandas as pd
import requests

from urllib.parse import urljoin
from bs4 import BeautifulSoup
from fuzzywuzzy import process
from tqdm import tqdm
tqdm.pandas()

# %%
CHART_URL = "https://www.erowid.org/general/big_chart.shtml"
headers    = {"User-Agent": "Mozilla/5.0"}

html   = requests.get(CHART_URL, headers=headers, verify=False).text
soup   = BeautifulSoup(html, "lxml")

# ## helpers ##########################################
def make_absolute(href: str | None) -> str | None:
    """prepend site root to relative links; leave None / empty untouched"""
    return urljoin(CHART_URL, href) if href else None

# ## extract ##########################################-
records           : list[dict]  = []
columns_by_table  : dict[str, list[str]] = {}

for table in soup.select("table.big-chart-surround"):
    category = table.get("id", "UNKNOWN").removeprefix("section-").upper()

    # header row:  <td>Category name</td> followed by 18 <th> containing <img alt="">
    header_ths = table.select("tr:first-child th")
    col_names  = [img["alt"] if (img := th.find("img")) and img.get("alt") else f"Col_{i}"
                  for i, th in enumerate(header_ths)]
    columns_by_table[category] = col_names

    # data rows
    for tr in table.select("tr")[1:]:
        cells        = tr.find_all(["td", "th"])
        first_cell   = cells[0]
        substance    = first_cell.get_text(strip=True)
        substance_url = make_absolute(first_cell.a["href"]) if first_cell.a else None

        row = {
            "Substance": substance,
            "URL"      : substance_url,
            "Category" : category,
        }

        # remaining cells map 1‑to‑1 onto col_names
        for col_name, th in zip(col_names, cells[1:]):
            row[col_name] = make_absolute(th.a["href"]) if th and th.a else None

        records.append(row)

# ## build DataFrame ####################################
erowid_data = pd.DataFrame(records).sort_values(["Category", "Substance"]).reset_index(drop=True)

# ## verify column consistency ##############################
first_cols = None
inconsistent = False
for cat, cols in columns_by_table.items():
    if first_cols is None:
        first_cols = cols
    elif cols != first_cols:
        inconsistent = True
        print(f"[WARN] Column mismatch in “{cat}”:\n       {cols}")

if not inconsistent:
    print("All category tables share identical columns.")

erowid_data.info(verbose=True)
erowid_data
# Out:
# c:\Users\James\anaconda3\envs\SparKG\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.erowid.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# All category tables share identical columns.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362 entries, 0 to 361
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Substance    362 non-null    object
#  1   URL          349 non-null    object
#  2   Category     362 non-null    object
#  3   MainPage     349 non-null    object
#  4   Basics       78 non-null     object
#  5   Images       305 non-null    object
#  6   Law          287 non-null    object
#  7   Dose         88 non-null     object
#  8   Experiences  20 non-null     object
#  9   FAQ          25 non-null     object
#  10  Effects      71 non-null     object
#  11  Chemistry    120 non-null    object
#  12  Testing      51 non-null     object
#  13  Health       26 non-null     object
#  14  History      67 non-null     object
#  15  Spiritual    1 non-null      object
#  16  Cultivation  16 non-null     object
#  17  Books        0 non-null      object
#  18  Journals     66 non-null     object
#  19  Writings     11 non-null     object
#  20  Media        19 non-null     object
# dtypes: object(21)
# memory usage: 59.5+ KB
#         Substance                                                URL Category  \
# 0             bee       https://www.erowid.org/animals/bee/bee.shtml  ANIMALS
# 1      blackwidow  https://www.erowid.org/animals/blackwidow/blac...  ANIMALS
# 2           frogs   https://www.erowid.org/animals/frogs/frogs.shtml  ANIMALS
# 3    phyllomedusa  https://www.erowid.org/animals/phyllomedusa/ph...  ANIMALS
# 4           toads   https://www.erowid.org/animals/toads/toads.shtml  ANIMALS
# ..            ...                                                ...      ...
# 357    selegiline  https://www.erowid.org/smarts/selegiline/seleg...   SMARTS
# 358    tryptophan  https://www.erowid.org/smarts/tryptophan/trypt...   SMARTS
# 359   vasopressin  https://www.erowid.org/smarts/vasopressin/vaso...   SMARTS
# 360   vinpocetine  https://www.erowid.org/smarts/vinpocetine/vinp...   SMARTS
# 361      vitamins  https://www.erowid.org/smarts/vitamins/vitamin...   SMARTS
#
#                                               MainPage  \
# 0         https://www.erowid.org/animals/bee/bee.shtml
# 1    https://www.erowid.org/animals/blackwidow/blac...
# 2     https://www.erowid.org/animals/frogs/frogs.shtml
# 3    https://www.erowid.org/animals/phyllomedusa/ph...
# 4     https://www.erowid.org/animals/toads/toads.shtml
# ..                                                 ...
# 357  https://www.erowid.org/smarts/selegiline/seleg...
# 358  https://www.erowid.org/smarts/tryptophan/trypt...
# 359  https://www.erowid.org/smarts/vasopressin/vaso...
# 360  https://www.erowid.org/smarts/vinpocetine/vinp...
# 361  https://www.erowid.org/smarts/vitamins/vitamin...
#
#                                                 Basics  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 357  https://www.erowid.org/smarts/selegiline/seleg...
# 358  https://www.erowid.org/smarts/tryptophan/trypt...
# 359  https://www.erowid.org/smarts/vasopressin/vaso...
# 360                                               None
# 361                                               None
#
#                                                 Images  \
# 0                                                 None
# 1    https://www.erowid.org/animals/blackwidow/blac...
# 2                                                 None
# 3    https://www.erowid.org/animals/phyllomedusa/ph...
# 4    https://www.erowid.org/animals/toads/toads_ima...
# ..                                                 ...
# 357  https://www.erowid.org/smarts/selegiline/seleg...
# 358  https://www.erowid.org/smarts/tryptophan/trypt...
# 359  https://www.erowid.org/smarts/vasopressin/vaso...
# 360  https://www.erowid.org/smarts/vinpocetine/vinp...
# 361                                               None
#
#                                                    Law  Dose  \
# 0                                                 None  None
# 1                                                 None  None
# 2                                                 None  None
# 3                                                 None  None
# 4    https://www.erowid.org/animals/toads/toads_law...  None
# ..                                                 ...   ...
# 357  https://www.erowid.org/smarts/selegiline/seleg...  None
# 358  https://www.erowid.org/smarts/tryptophan/trypt...  None
# 359  https://www.erowid.org/smarts/vasopressin/vaso...  None
# 360                                               None  None
# 361                                               None  None
#
#                                            Experiences   FAQ  ...  \
# 0                                                 None  None  ...
# 1    https://www.erowid.org/experiences/subs/exp_An...  None  ...
# 2                                                 None  None  ...
# 3                                                 None  None  ...
# 4                                                 None  None  ...
# ..                                                 ...   ...  ...
# 357                                               None  None  ...
# 358  https://www.erowid.org/experiences/subs/exp_Tr...  None  ...
# 359  https://www.erowid.org/experiences/subs/exp_Va...  None  ...
# 360                                               None  None  ...
# 361                                               None  None  ...
#
#                                              Chemistry Testing Health History  \
# 0                                                 None    None   None    None
# 1                                                 None    None   None    None
# 2                                                 None    None   None    None
# 3                                                 None    None   None    None
# 4                                                 None    None   None    None
# ..                                                 ...     ...    ...     ...
# 357  https://www.erowid.org/smarts/selegiline/seleg...    None   None    None
# 358  https://www.erowid.org/smarts/tryptophan/trypt...    None   None    None
# 359  https://www.erowid.org/smarts/vasopressin/vaso...    None   None    None
# 360  https://www.erowid.org/smarts/vinpocetine/vinp...    None   None    None
# 361                                               None    None   None    None
#
#     Spiritual Cultivation Books  \
# 0        None        None  None
# 1        None        None  None
# 2        None        None  None
# 3        None        None  None
# 4        None        None  None
# ..        ...         ...   ...
# 357      None        None  None
# 358      None        None  None
# 359      None        None  None
# 360      None        None  None
# 361      None        None  None
#
#                                               Journals Writings Media
# 0                                                 None     None  None
# 1                                                 None     None  None
# 2                                                 None     None  None
# 3                                                 None     None  None
# 4    https://www.erowid.org/animals/toads/toads_jou...     None  None
# ..                                                 ...      ...   ...
# 357  https://www.erowid.org/smarts/selegiline/seleg...     None  None
# 358                                               None     None  None
# 359  https://www.erowid.org/smarts/vasopressin/vaso...     None  None
# 360                                               None     None  None
# 361                                               None     None  None
#
# [362 rows x 21 columns]

# %%
# ################################################--
# 1. compare “MainPage” vs. substance URL
# ################################################--
erowid_data["Main_equals_URL"] = erowid_data["MainPage"].fillna("") == erowid_data["URL"].fillna("")

mismatched = erowid_data.loc[~erowid_data["Main_equals_URL"], 
                    ["Category", "Substance", "URL", "MainPage"]]

if mismatched.empty:
    print("Every row has identical URL and MainPage values.")
else:
    print(f"Found {len(mismatched)} rows where they differ:")
    print(mismatched.to_string(index=False))
# Out:
# Every row has identical URL and MainPage values.

# %%
erowid_data = erowid_data.drop(['URL','Main_equals_URL','Images','Books'], axis=1)
erowid_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362 entries, 0 to 361
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Substance    362 non-null    object
#  1   Category     362 non-null    object
#  2   MainPage     349 non-null    object
#  3   Basics       78 non-null     object
#  4   Law          287 non-null    object
#  5   Dose         88 non-null     object
#  6   Experiences  20 non-null     object
#  7   FAQ          25 non-null     object
#  8   Effects      71 non-null     object
#  9   Chemistry    120 non-null    object
#  10  Testing      51 non-null     object
#  11  Health       26 non-null     object
#  12  History      67 non-null     object
#  13  Spiritual    1 non-null      object
#  14  Cultivation  16 non-null     object
#  15  Journals     66 non-null     object
#  16  Writings     11 non-null     object
#  17  Media        19 non-null     object
# dtypes: object(18)
# memory usage: 51.0+ KB

# %%
substances_of_interest = pd.read_csv('../data/substances_of_interest_list.csv', encoding="utf-8-sig")
substances_of_interest
# Out:
#                         drug
# 0               2,6-Xylidine
# 1   2-amino-5-chloropyridine
# 2         2-fluoro-2-oxo PCE
# 3        2-Oxo-3-hydroxy-LSD
# 4    3-hydroxy flubromazepam
# ..                       ...
# 72           Speciociliatine
# 73                 Temazepam
# 74                  Xylazine
# 75                  Zolpidem
# 76                 Zopiclone
#
# [77 rows x 1 columns]

# %%
matching_erowid_data = substances_of_interest.copy()
for col in erowid_data.columns:
    if col not in matching_erowid_data.columns:
        matching_erowid_data[col] = None          

for index, row in matching_erowid_data.iterrows():
    drug = row["drug"]  

    # Find the closest match in the matching_erowid_data DataFrame
    match, score = process.extractOne(drug, erowid_data["Substance"].tolist())
    if score > 98:  ############################### 
        src_row = erowid_data.loc[erowid_data["Substance"] == match].iloc[0]

        # copy every column’s value into the target DataFrame
        for col in erowid_data.columns:
            matching_erowid_data.at[index, col] = src_row[col]
        print(match)
# Out:
# buprenorphine
# codeine
# cyclobenzaprine
# diphenhydramine
# fentanyl
# gabapentin
# hydrocodone
# hydromorphone
# ketamine
# lorazepam
# lsd
# mda
# mdma
# meperidine
# methadone
# morphine
# naltrexone
# oxycodone
# oxymorphone
# pregabalin
# psilocybin
# temazepam
# zolpidem
# zopiclone

# %%
for index, row in matching_erowid_data.iterrows():
    if not pd.isna(row["Substance"]):
        continue
    drug = row["drug"]  
    # Find the top three closest matches 
    top_matches = process.extract(drug, erowid_data["Substance"].tolist(), limit=3)
    print("########################################")
    for match, score in top_matches:
        if score > 50:  ################################## 
            print(f"{drug} | {match} | {score}")

#I skimmed through these to find errors
# Out:
# ########################################
# 2,6-Xylidine | doi | 60
# 2,6-Xylidine | lsd | 60
# 2,6-Xylidine | clonidine | 57
# ########################################
# 2-amino-5-chloropyridine | 5-mapb | 86
# 2-amino-5-chloropyridine | mint | 68
# 2-amino-5-chloropyridine | chlorpromazine | 64
# ########################################
# 2-fluoro-2-oxo PCE | 2ce | 60
# 2-fluoro-2-oxo PCE | pcp | 60
# ########################################
# 2-Oxo-3-hydroxy-LSD | lsd | 90
# 2-Oxo-3-hydroxy-LSD | 1p-lsd | 86
# 2-Oxo-3-hydroxy-LSD | 3-meo-pcp | 86
# ########################################
# 3-hydroxy flubromazepam | bromazepam | 90
# 3-hydroxy flubromazepam | 3-meo-pcp | 86
# 3-hydroxy flubromazepam | amt | 72
# ########################################
# 3-hydroxy flubromazepam glucuronide | bromazepam | 90
# 3-hydroxy flubromazepam glucuronide | 3-meo-pcp | 86
# 3-hydroxy flubromazepam glucuronide | lorazepam | 70
# ########################################
# 4-ANPP | pcp | 72
# 4-ANPP | a-pvp | 55
# 4-ANPP | mptp | 51
# ########################################
# 4-HIAA | iap | 60
# 4-HIAA | echinacea | 53
# 4-HIAA | kava | 51
# ########################################
# 6-acetylmorphine | morphine | 90
# 6-acetylmorphine | desomorphine | 64
# 6-acetylmorphine | acetaminophen | 62
# ########################################
# 7-aminoclonazepam | clonazepam | 90
# 7-aminoclonazepam | lorazepam | 80
# 7-aminoclonazepam | mint | 68
# ########################################
# 7-hydroxymitragynine | mipt | 68
# 7-hydroxymitragynine | mint | 68
# 7-hydroxymitragynine | amt | 60
# ########################################
# 7-OH-CBD glucuronide | det | 72
# 7-OH-CBD glucuronide | 2cb | 60
# 7-OH-CBD glucuronide | 2cd | 60
# ########################################
# 8-aminoclonazolam | clonazepam | 72
# 8-aminoclonazolam | mint | 68
# 8-aminoclonazolam | alprazolam | 63
# ########################################
# ########################################
# ########################################
# alpha-hydroxyalprazolam | alprazolam | 90
# alpha-hydroxyalprazolam | amt | 72
# alpha-hydroxyalprazolam | triazolam | 70
# ########################################
# alpha-hydroxybromazolam | bromazepam | 72
# alpha-hydroxybromazolam | midazolam | 70
# alpha-hydroxybromazolam | triazolam | 70
# ########################################
# Amphetamine | amphetamines | 96
# Amphetamine | 4_fluoroamphetamine | 90
# Amphetamine | methoxetamine | 75
# ########################################
# Benzoylecgonine | clonidine | 68
# Benzoylecgonine | cocaine | 64
# Benzoylecgonine | codeine | 64
# ########################################
# Bromazolam | bromazepam | 80
# Bromazolam | midazolam | 74
# Bromazolam | triazolam | 74
# ########################################
# Carfentanil | fentanyl | 74
# Carfentanil | acetylfentanyl | 64
# Carfentanil | aet | 60
# ########################################
# CBD | 2cb | 67
# CBD | 2cd | 67
# CBD | 2cb_fly | 60
# ########################################
# delta-8-THC-COOH | 2cc | 60
# delta-8-THC-COOH | aet | 60
# delta-8-THC-COOH | det | 60
# ########################################
# delta-9-THC-COOH | 2cc | 60
# delta-9-THC-COOH | aet | 60
# delta-9-THC-COOH | det | 60
# ########################################
# EDDP | dpt | 57
# ########################################
# Flubromazepam | bromazepam | 87
# Flubromazepam | flurazepam | 87
# Flubromazepam | flunitrazepam | 77
# ########################################
# MDMB-4en-PINACA butanoic acid | mbdb | 68
# MDMB-4en-PINACA butanoic acid | mdma | 68
# MDMB-4en-PINACA butanoic acid | echinacea | 60
# ########################################
# Meprobamate | yerba_mate | 76
# Meprobamate | mdpr | 68
# Meprobamate | dmae | 68
# ########################################
# Methamphetamine | met | 90
# Methamphetamine | meth | 90
# Methamphetamine | amphetamines | 81
# ########################################
# Metonitazene | met | 90
# Metonitazene | meth | 68
# Metonitazene | melatonin | 67
# ########################################
# Mitragynine | mipt | 68
# Mitragynine | mint | 68
# Mitragynine | amitriptyline | 67
# ########################################
# N,N-dimethylpentylone | met | 90
# N,N-dimethylpentylone | meth | 90
# N,N-dimethylpentylone | ethylene | 79
# ########################################
# N-desethylmetonitazene | met | 90
# N-desethylmetonitazene | ethylene | 68
# N-desethylmetonitazene | meth | 68
# ########################################
# Norbuprenorphine | buprenorphine | 90
# Norbuprenorphine | morphine | 79
# Norbuprenorphine | bupropion | 64
# ########################################
# Norcarfentanil | fentanyl | 79
# Norcarfentanil | coca | 68
# Norcarfentanil | aet | 60
# ########################################
# Nordiazepam | diazepam | 84
# Nordiazepam | lorazepam | 80
# Nordiazepam | nimetazepam | 73
# ########################################
# Norfentanyl | fentanyl | 84
# Norfentanyl | acetylfentanyl | 64
# Norfentanyl | aet | 60
# ########################################
# Norketamine | ketamine | 84
# Norketamine | mint | 68
# Norketamine | methoxetamine | 67
# ########################################
# Normeperidine | meperidine | 87
# Normeperidine | nbome | 72
# Normeperidine | risperidone | 67
# ########################################
# Noroxycodone | oxycodone | 86
# Noroxycodone | hydrocodone | 70
# Noroxycodone | codeine | 69
# ########################################
# N-Pyrrolidinoetonitazene | bee | 60
# N-Pyrrolidinoetonitazene | aet | 60
# N-Pyrrolidinoetonitazene | det | 60
# ########################################
# O-desmethyltramadol | met | 90
# O-desmethyltramadol | meth | 90
# O-desmethyltramadol | tramadol | 90
# ########################################
# ortho-methylfentanyl | met | 90
# ortho-methylfentanyl | meth | 90
# ortho-methylfentanyl | fentanyl | 90
# ########################################
# Oxazepam | lorazepam | 82
# Oxazepam | bromazepam | 78
# Oxazepam | clonazepam | 78
# ########################################
# para-Fluorofentanyl | fentanyl | 90
# para-Fluorofentanyl | acetylfentanyl | 61
# para-Fluorofentanyl | aet | 60
# ########################################
# para-Fluoronorfentanyl | fentanyl | 90
# para-Fluoronorfentanyl | aet | 60
# para-Fluoronorfentanyl | det | 60
# ########################################
# Pentylone | methylone | 78
# Pentylone | ethylene | 71
# Pentylone | peyote | 67
# ########################################
# Phencyclidine | cyclizine | 73
# Phencyclidine | ephedrine | 64
# Phencyclidine | methoxphenidine | 64
# ########################################
# Psilocin | psilocybin | 89
# Psilocin | capsaicin | 71
# Psilocin | 2ci | 60
# ########################################
# R-HHC-COOH | 2cc | 60
# R-HHC-COOH | cacao | 54
# ########################################
# S-HHC-COOH | 2cc | 60
# S-HHC-COOH | cacao | 54
# ########################################
# Speciociliatine | coca | 68
# Speciociliatine | cocaine | 64
# Speciociliatine | scopolamine | 62
# ########################################
# Xylazine | cyclizine | 71
# Xylazine | olanzapine | 67
# Xylazine | amitriptyline | 64

# %%
# the fuzzy matching missed 2 matches
# Amphetamine and Methamphetamine
def patch_row(target_df, drug_name, erowid_name):
    # full source Series 
    src_row = erowid_data.loc[erowid_data["Substance"] == erowid_name].iloc[0]
    # write every column into the matching row of the target DataFrame
    for col in erowid_data.columns:
        target_df.loc[target_df["drug"] == drug_name, col] = src_row[col]

patch_row(matching_erowid_data, "Amphetamine", "amphetamines")
patch_row(matching_erowid_data, "Methamphetamine", "meth")

matching_erowid_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   drug         77 non-null     object
#  1   Substance    26 non-null     object
#  2   Category     26 non-null     object
#  3   MainPage     26 non-null     object
#  4   Basics       6 non-null      object
#  5   Law          25 non-null     object
#  6   Dose         10 non-null     object
#  7   Experiences  0 non-null      object
#  8   FAQ          5 non-null      object
#  9   Effects      9 non-null      object
#  10  Chemistry    9 non-null      object
#  11  Testing      11 non-null     object
#  12  Health       6 non-null      object
#  13  History      9 non-null      object
#  14  Spiritual    0 non-null      object
#  15  Cultivation  0 non-null      object
#  16  Journals     5 non-null      object
#  17  Writings     4 non-null      object
#  18  Media        4 non-null      object
# dtypes: object(19)
# memory usage: 11.6+ KB

# %%
url_cols = [c for c in matching_erowid_data.columns
            if c not in ("drug", "Substance", "Category")]

sets = []
for _, row in matching_erowid_data.iterrows():
    drug = row["drug"]
    substance = row["Substance"]
    category = row["Category"]
    for col in url_cols:
        url = row[col]
        if isinstance(url, str) and url.strip():        # non‑empty link
            sets.append((drug, substance, category, col, url.strip()))

print(f"{len(sets)} (drug, substance, category, col, url) sets")

long_matching_erowid_data = pd.DataFrame(sets,
    columns=["drug","substance","category","erowid_column","url"]
)   

long_matching_erowid_data.info(verbose=True)
long_matching_erowid_data.to_csv('../data/long_matching_erowid_data.csv', index=False, encoding="utf-8-sig")
long_matching_erowid_data
# Out:
# 129 (drug, substance, category, col, url) sets
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   drug           129 non-null    object
#  1   substance      129 non-null    object
#  2   category       129 non-null    object
#  3   erowid_column  129 non-null    object
#  4   url            129 non-null    object
# dtypes: object(5)
# memory usage: 5.2+ KB
#             drug     substance   category erowid_column  \
# 0    Amphetamine  amphetamines  CHEMICALS      MainPage
# 1    Amphetamine  amphetamines  CHEMICALS        Basics
# 2    Amphetamine  amphetamines  CHEMICALS           Law
# 3    Amphetamine  amphetamines  CHEMICALS       Effects
# 4    Amphetamine  amphetamines  CHEMICALS     Chemistry
# ..           ...           ...        ...           ...
# 124    Temazepam     temazepam     PHARMS      MainPage
# 125    Temazepam     temazepam     PHARMS           Law
# 126     Zolpidem      zolpidem     PHARMS      MainPage
# 127     Zolpidem      zolpidem     PHARMS           Law
# 128    Zopiclone     zopiclone     PHARMS      MainPage
#
#                                                    url
# 0    https://www.erowid.org/chemicals/amphetamines/...
# 1    https://www.erowid.org/chemicals/amphetamines/...
# 2    https://www.erowid.org/chemicals/amphetamines/...
# 3    https://www.erowid.org/chemicals/amphetamines/...
# 4    https://www.erowid.org/chemicals/amphetamines/...
# ..                                                 ...
# 124  https://www.erowid.org/pharms/temazepam/temaze...
# 125  https://www.erowid.org/pharms/temazepam/temaze...
# 126  https://www.erowid.org/pharms/zolpidem/zolpide...
# 127  https://www.erowid.org/pharms/zolpidem/zolpide...
# 128  https://www.erowid.org/pharms/zopiclone/zopicl...
#
# [129 rows x 5 columns]

# %%
# all unique URLs
url_cols = [c for c in long_matching_erowid_data.columns
            if c not in ("drug", "Substance", "Category")]

unique_urls = (
    pd.unique(
        long_matching_erowid_data[url_cols]
        .values                       # ndarray of all url‑cells
        .ravel("K")                   # flatten to 1‑D
    )
)

# drop NaNs / empty strings and convert to a clean Python list
unique_urls = [u for u in unique_urls if isinstance(u, str) and u.strip()]

print(f"{len(unique_urls)} unique URLs")
unique_urls
# Out:
# 170 unique URLs
# ['amphetamines',
#  'buprenorphine',
#  'codeine',
#  'cyclobenzaprine',
#  'diphenhydramine',
#  'fentanyl',
#  'gabapentin',
#  'hydrocodone',
#  'hydromorphone',
#  'ketamine',
#  'lorazepam',
#  'lsd',
#  'mda',
#  'mdma',
#  'meperidine',
#  'methadone',
#  'meth',
#  'morphine',
#  'naltrexone',
#  'oxycodone',
#  'oxymorphone',
#  'pregabalin',
#  'psilocybin',
#  'temazepam',
#  'zolpidem',
#  'zopiclone',
#  'CHEMICALS',
#  'PHARMS',
#  'MainPage',
#  'Basics',
#  'Law',
#  'Effects',
#  'Chemistry',
#  'Testing',
#  'Health',
#  'History',
#  'Journals',
#  'Media',
#  'FAQ',
#  'Dose',
#  'Writings',
#  'https://www.erowid.org/chemicals/amphetamines/amphetamines.shtml',
#  'https://www.erowid.org/chemicals/amphetamines/amphetamines_basics.shtml',
#  'https://www.erowid.org/chemicals/amphetamines/amphetamines_law.shtml',
#  'https://www.erowid.org/chemicals/amphetamines/amphetamines_effects.shtml',
#  'https://www.erowid.org/chemicals/amphetamines/amphetamines_chemistry.shtml',
#  'https://www.erowid.org/chemicals/amphetamines/amphetamines_testing.shtml',
#  'https://www.erowid.org/chemicals/amphetamines/amphetamines_health.shtml',
#  'https://www.erowid.org/chemicals/amphetamines/amphetamines_timeline.php',
#  'https://www.erowid.org/chemicals/amphetamines/amphetamines_journal.shtml',
#  'https://www.erowid.org/chemicals/amphetamines/amphetamines_media.shtml',
#  'https://www.erowid.org/pharms/buprenorphine/buprenorphine.shtml',
#  'https://www.erowid.org/pharms/buprenorphine/buprenorphine_law.shtml',
#  'https://www.erowid.org/pharms/buprenorphine/buprenorphine_testing.shtml',
#  'https://www.erowid.org/pharms/codeine/codeine.shtml',
#  'https://www.erowid.org/pharms/codeine/codeine_law.shtml',
#  'https://www.erowid.org/pharms/codeine/codeine_faq.shtml',
#  'https://www.erowid.org/pharms/codeine/codeine_chemistry.shtml',
#  'https://www.erowid.org/pharms/cyclobenzaprine/cyclobenzaprine.shtml',
#  'https://www.erowid.org/pharms/cyclobenzaprine/cyclobenzaprine_law.shtml',
#  'https://www.erowid.org/pharms/diphenhydramine/diphenhydramine.shtml',
#  'https://www.erowid.org/pharms/diphenhydramine/diphenhydramine_law.shtml',
#  'https://www.erowid.org/pharms/diphenhydramine/diphenhydramine_dose.shtml',
#  'https://www.erowid.org/pharms/diphenhydramine/diphenhydramine_effects.shtml',
#  'https://www.erowid.org/pharms/diphenhydramine/diphenhydramine_testing.shtml',
#  'https://www.erowid.org/pharms/fentanyl/fentanyl.shtml',
#  'https://www.erowid.org/pharms/fentanyl/fentanyl_law.shtml',
#  'https://www.erowid.org/pharms/fentanyl/fentanyl_dose.shtml',
#  'https://www.erowid.org/pharms/gabapentin/gabapentin.shtml',
#  'https://www.erowid.org/pharms/gabapentin/gabapentin_law.shtml',
#  'https://www.erowid.org/pharms/hydrocodone/hydrocodone.shtml',
#  'https://www.erowid.org/pharms/hydrocodone/hydrocodone_law.shtml',
#  'https://www.erowid.org/pharms/hydrocodone/hydrocodone_dose.shtml',
#  'https://www.erowid.org/pharms/hydrocodone/hydrocodone_effects.shtml',
#  'https://www.erowid.org/pharms/hydrocodone/hydrocodone_chemistry.shtml',
#  'https://www.erowid.org/pharms/hydrocodone/hydrocodone_testing.shtml',
#  'https://www.erowid.org/pharms/hydrocodone/hydrocodone_health.shtml',
#  'https://www.erowid.org/pharms/hydromorphone/hydromorphone.shtml',
#  'https://www.erowid.org/pharms/hydromorphone/hydromorphone_law.shtml',
#  'https://www.erowid.org/pharms/hydromorphone/hydromorphone_testing.shtml',
#  'https://www.erowid.org/chemicals/ketamine/ketamine.shtml',
#  'https://www.erowid.org/chemicals/ketamine/ketamine_basics.shtml',
#  'https://www.erowid.org/chemicals/ketamine/ketamine_law.shtml',
#  'https://www.erowid.org/chemicals/ketamine/ketamine_dose.shtml',
#  'https://www.erowid.org/chemicals/ketamine/ketamine_faq.shtml',
#  'https://www.erowid.org/chemicals/ketamine/ketamine_effects.shtml',
#  'https://www.erowid.org/chemicals/ketamine/ketamine_chemistry.shtml',
#  'https://www.erowid.org/chemicals/ketamine/ketamine_testing.shtml',
#  'https://www.erowid.org/chemicals/ketamine/ketamine_health.shtml',
#  'https://www.erowid.org/chemicals/ketamine/ketamine_timeline.php',
#  'https://www.erowid.org/chemicals/ketamine/ketamine_journal.shtml',
#  'https://www.erowid.org/chemicals/ketamine/ketamine_writings.shtml',
#  'https://www.erowid.org/pharms/lorazepam/lorazepam.shtml',
#  'https://www.erowid.org/pharms/lorazepam/lorazepam_law.shtml',
#  'https://www.erowid.org/chemicals/lsd/lsd.shtml',
#  'https://www.erowid.org/chemicals/lsd/lsd_basics.shtml',
#  'https://www.erowid.org/chemicals/lsd/lsd_law.shtml',
#  'https://www.erowid.org/chemicals/lsd/lsd_dose.shtml',
#  'https://www.erowid.org/chemicals/lsd/lsd_faq.shtml',
#  'https://www.erowid.org/chemicals/lsd/lsd_effects.shtml',
#  'https://www.erowid.org/chemicals/lsd/lsd_chemistry.shtml',
#  'https://www.erowid.org/chemicals/lsd/lsd_testing.shtml',
#  'https://www.erowid.org/chemicals/lsd/lsd_health.shtml',
#  'https://www.erowid.org/chemicals/lsd/lsd_timeline.php',
#  'https://www.erowid.org/chemicals/lsd/lsd_journal.shtml',
#  'https://www.erowid.org/chemicals/lsd/lsd_writings.shtml',
#  'https://www.erowid.org/chemicals/lsd/lsd_media.shtml',
#  'https://www.erowid.org/chemicals/mda/mda.shtml',
#  'https://www.erowid.org/chemicals/mda/mda_law.shtml',
#  'https://www.erowid.org/chemicals/mda/mda_dose.shtml',
#  'https://www.erowid.org/chemicals/mda/mda_effects.shtml',
#  'https://www.erowid.org/chemicals/mda/mda_timeline.php',
#  'https://www.erowid.org/chemicals/mdma/mdma.shtml',
#  'https://www.erowid.org/chemicals/mdma/mdma_basics.shtml',
#  'https://www.erowid.org/chemicals/mdma/mdma_law.shtml',
#  'https://www.erowid.org/chemicals/mdma/mdma_dose.shtml',
#  'https://www.erowid.org/chemicals/mdma/mdma_faq.shtml',
#  'https://www.erowid.org/chemicals/mdma/mdma_effects.shtml',
#  'https://www.erowid.org/chemicals/mdma/mdma_chemistry.shtml',
#  'https://www.erowid.org/chemicals/mdma/mdma_testing.shtml',
#  'https://www.erowid.org/chemicals/mdma/mdma_health.shtml',
#  'https://www.erowid.org/chemicals/mdma/mdma_timeline.php',
#  'https://www.erowid.org/chemicals/mdma/mdma_journal.shtml',
#  'https://www.erowid.org/chemicals/mdma/mdma_writings.shtml',
#  'https://www.erowid.org/chemicals/mdma/mdma_media.shtml',
#  'https://www.erowid.org/pharms/meperidine/meperidine.shtml',
#  'https://www.erowid.org/pharms/meperidine/meperidine_law.shtml',
#  'https://www.erowid.org/chemicals/methadone/methadone.shtml',
#  'https://www.erowid.org/chemicals/methadone/methadone_law.shtml',
#  'https://www.erowid.org/chemicals/methadone/methadone_testing.shtml',
#  'https://www.erowid.org/chemicals/meth/meth.shtml',
#  'https://www.erowid.org/chemicals/meth/meth_basics.shtml',
#  'https://www.erowid.org/chemicals/meth/meth_law.shtml',
#  'https://www.erowid.org/chemicals/meth/meth_dose.shtml',
#  'https://www.erowid.org/chemicals/meth/meth_faq.shtml',
#  'https://www.erowid.org/chemicals/meth/meth_effects.shtml',
#  'https://www.erowid.org/chemicals/meth/meth_chemistry.shtml',
#  'https://www.erowid.org/chemicals/meth/meth_testing.shtml',
#  'https://www.erowid.org/chemicals/meth/meth_timeline.php',
#  'https://www.erowid.org/chemicals/meth/meth_journal.shtml',
#  'https://www.erowid.org/chemicals/meth/meth_writings.shtml',
#  'https://www.erowid.org/chemicals/meth/meth_media.shtml',
#  'https://www.erowid.org/pharms/morphine/morphine.shtml',
#  'https://www.erowid.org/pharms/morphine/morphine_law.shtml',
#  'https://www.erowid.org/pharms/morphine/morphine_timeline.php',
#  'https://www.erowid.org/pharms/naltrexone/naltrexone.shtml',
#  'https://www.erowid.org/pharms/naltrexone/naltrexone_law.shtml',
#  'https://www.erowid.org/pharms/oxycodone/oxycodone.shtml',
#  'https://www.erowid.org/pharms/oxycodone/oxycodone_basics.shtml',
#  'https://www.erowid.org/pharms/oxycodone/oxycodone_law.shtml',
#  'https://www.erowid.org/pharms/oxycodone/oxycodone_dose.shtml',
#  'https://www.erowid.org/pharms/oxycodone/oxycodone_effects.shtml',
#  'https://www.erowid.org/pharms/oxycodone/oxycodone_chemistry.shtml',
#  'https://www.erowid.org/pharms/oxycodone/oxycodone_testing.shtml',
#  'https://www.erowid.org/pharms/oxycodone/oxycodone_health.shtml',
#  'https://www.erowid.org/pharms/oxycodone/oxycodone_timeline.php',
#  'https://www.erowid.org/pharms/oxymorphone/oxymorphone.shtml',
#  'https://www.erowid.org/pharms/oxymorphone/oxymorphone_law.shtml',
#  'https://www.erowid.org/pharms/pregabalin/pregabalin.shtml',
#  'https://www.erowid.org/pharms/pregabalin/pregabalin_law.shtml',
#  'https://www.erowid.org/chemicals/psilocybin/psilocybin.shtml',
#  'https://www.erowid.org/chemicals/psilocybin/psilocybin_law.shtml',
#  'https://www.erowid.org/chemicals/psilocybin/psilocybin_dose.shtml',
#  'https://www.erowid.org/chemicals/psilocybin/psilocybin_chemistry.shtml',
#  'https://www.erowid.org/chemicals/psilocybin/psilocybin_timeline.php',
#  'https://www.erowid.org/pharms/temazepam/temazepam.shtml',
#  'https://www.erowid.org/pharms/temazepam/temazepam_law.shtml',
#  'https://www.erowid.org/pharms/zolpidem/zolpidem.shtml',
#  'https://www.erowid.org/pharms/zolpidem/zolpidem_law.shtml',
#  'https://www.erowid.org/pharms/zopiclone/zopiclone.shtml']
