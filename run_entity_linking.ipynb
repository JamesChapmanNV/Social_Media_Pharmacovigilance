# %%
import pandas as pd
import json
import os
import re
from tqdm import tqdm
tqdm.pandas()

from utils import (
    get_tweets_dataset, 
    extract_responses,
    extract_JSON_labels_and_explanations,
    extract_drug_labels,
    extract_T_F_labels, 
    match_terms,
    get_confusion_matrix_and_metrics,
)
from llm_manager import (
    run_prompt_on_llm,
### paid #################
    # get_claude_response, 
    # get_openai_response, 
    # get_perplexity_response,
    get_openai_gpt4omini_response,
    get_openai_o4mini_response,
### local #################
    get_llama_response, 
    get_qwen_4b_response,                        
    #get_deepseek_qwen_response,
    # get_qwen_response,
    # get_mistral_response,
    cleanup_llama,
    cleanup_qwen,
    cleanup_qwen_4b,
    cleanup_deepseek_qwen,
    cleanup_mistral,
)

# %%
tweets = get_tweets_dataset()
SEED = 777
tweets = ( tweets.sample(n=1_000, random_state=SEED, replace=False)
                 .sort_index()
                 .reset_index(drop=True)
)
tweets.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   text                       1000 non-null   object
#  1   label                      1000 non-null   object
#  2   tweet_num                  1000 non-null   int64
#  3   found_terms                1000 non-null   object
#  4   found_index_terms          1000 non-null   object
#  5   GPT_found_terms            1000 non-null   object
#  6   GPT_found_index_terms      1000 non-null   object
#  7   pubchem_found_terms        1000 non-null   object
#  8   pubchem_found_index_terms  1000 non-null   object
#  9   redmed_found_terms         1000 non-null   object
#  10  redmed_found_index_terms   1000 non-null   object
#  11  DEA_found_terms            1000 non-null   object
#  12  DEA_found_index_terms      1000 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 101.7+ KB

# %%
entity_linking_prompt = """
### Role
You moderate social‑media content for drug‑related references.

### Tasks
Given a post:
1. Detect every word or phrase (slang, euphemism, synonym, cultural references) that refers to an illicit drug or substance.
   • Include illegal, RX, OTC, or recreational drugs (using, buying, promoting, encouraging or glorifying drug use).
2. Link each detected phrase to its matching **Index Term** (see list below). 
   • If the drug is *not* in the list, use "other".
3. Return **only** a valid JSON array, one object per match, using the schema  
   `{"index_term": "<Index Term or other>", "matched_phrase": "<exact text>"}`.

### Output: exact format
[
  {"index_term": "Codeine", "matched_phrase": "lean"},
  {"index_term": "Codeine", "matched_phrase": "codeine"},
  ...
]    

### Index Terms
2,6-Xylidine (2,6-Dimethylaniline, 2‑amino‑1,3‑dimethylbenzene) – A toxic aniline derivative used as an intermediate in manufacturing local anesthetics and dyes.
2‑Amino‑5‑chloropyridine (5‑Chloro‑2‑aminopyridine) – A breakdown product of the sleep drug zopiclone that serves as a urinary marker in drug tests.
2‑Fluoro‑2‑oxo PCE (CanKet, 2F‑NENDCK, 2‑FXE) – A novel ketamine‑like dissociative anesthetic sold illicitly for its hallucinogenic effects.
2‑Oxo‑3‑hydroxy‑LSD (2‑oxo‑3‑hydroxy lysergic acid diethylamide, oxo‑HO‑LSD) – The principal urinary metabolite of LSD produced after psychedelic use.
3‑Hydroxy flubromazepam () – A primary metabolite of the designer benzodiazepine flubromazepam detectable in urine for an extended period.
3‑Hydroxy flubromazepam glucuronide () – The glucuronidated form of 3‑hydroxy flubromazepam that aids bodily elimination of the parent drug.
4‑ANPP (Despropionyl fentanyl, 4‑anilino‑N‑phenethylpiperidine) – A key precursor and metabolite of fentanyl often found as an impurity in illicit opioid production.
4‑HIAA (4‑Hydroxyindole‑3‑acetic acid) – The main inactive metabolite excreted after psilocybin ingestion (“magic mushrooms”).
6‑Acetylmorphine (6‑Monoacetylmorphine, 6‑MAM) – An active intermediate metabolite formed almost immediately after heroin use.
7‑Aminoclonazepam () – The chief urinary metabolite of the prescription benzodiazepine clonazepam.
7‑Hydroxymitragynine (7‑OH‑Mitragynine) – A potent kratom alkaloid and human metabolite that produces strong opioid‑like effects.
7‑OH‑CBD glucuronide () – A conjugated metabolite formed during cannabidiol (CBD) metabolism and excreted in urine.
8‑Aminoclonazolam () – A metabolite indicating use of the designer benzodiazepine clonazolam in toxicology screens.
8R‑OH‑R‑HHC (8α‑hydroxy‑9β‑HHC) – A hydroxylated metabolite of the synthetic cannabinoid HHC produced during metabolism.
8S‑OH‑R‑HHC (8β‑hydroxy‑9β‑HHC) – The epimeric hydroxylated metabolite of R‑HHC likewise formed in users of HHC products.
α‑Hydroxyalprazolam (α‑OH‑alprazolam) – The major active metabolite of alprazolam (Xanax) contributing to its sedative effects.
α‑Hydroxybromazolam (α‑OH‑bromazolam) – An oxidative metabolite used to confirm bromazolam ingestion.
Amphetamine (Speed, Bennies, Adderall) – A central nervous system stimulant prescribed for ADHD that is frequently abused for euphoria and wakefulness.
Benzoylecgonine (BZE, Ecgonine benzoate) – The primary metabolite of cocaine measured in urine drug testing.
Bromazolam (XLI‑268, Fake Xanax) – A designer benzodiazepine sold illicitly that mimics the sedative effects of alprazolam.
Buprenorphine (Suboxone, Subutex, Bupe) – A partial opioid agonist used to treat opioid dependence and moderate pain with a ceiling on respiratory depression.
Carfentanil (Wildnil, Elephant tranquilizer) – An ultra‑potent fentanyl analog used for large‑animal sedation and deadly in microgram doses to humans.
CBD (Cannabidiol, Epidiolex) – A non‑intoxicating cannabinoid with antiepileptic and anxiolytic properties approved for certain seizure disorders.
Codeine (Lean, Purple Drank, Schoolboy) – A mild opioid painkiller and cough suppressant that is widely abused in syrup form for euphoric “lean.”
Cyclobenzaprine (Flexeril, Amrix, Fexmid) – A muscle relaxant related to tricyclic antidepressants used for short‑term relief of muscle spasms.
delta‑8‑THC‑COOH (11‑nor‑9‑carboxy‑delta‑8‑THC) – The main inactive urinary metabolite indicating use of delta‑8‑THC products.
delta‑9‑THC‑COOH (11‑nor‑9‑carboxy‑THC, THC‑COOH) – The principal inactive metabolite of cannabis’ delta‑9‑THC detected in urine screens.
Diphenhydramine (Benadryl, Nytol) – A first‑generation antihistamine with sedative and anticholinergic effects that is sometimes misused at high doses.
EDDP () – The inactive metabolite of methadone used to verify methadone compliance in treatment programs.
Fentanyl (China White, Apache, Duragesic) – A synthetic opioid 50–100 times stronger than morphine that drives many overdose deaths.
Flubromazepam () – A long‑acting “research chemical” benzodiazepine producing prolonged sedation and anxiolysis.
Gabapentin (Neurontin, Gralise, Gabbies) – An anticonvulsant prescribed for neuropathic pain and seizures that carries some abuse potential.
Hydrocodone (Vicodin, Norco, Vike) – A commonly prescribed semi‑synthetic opioid painkiller frequently diverted for nonmedical use.
Hydromorphone (Dilaudid, Dillies) – A potent morphine derivative used for severe pain with rapid onset and high addiction risk.
Ketamine (Special K, Keta, Ketalar) – A dissociative anesthetic causing trance‑like analgesia and hallucinations prized both medically and recreationally.
Lorazepam (Ativan) – A short‑acting benzodiazepine anxiolytic used for anxiety, insomnia, and seizure emergencies.
LSD (Acid, Lucy, Delysid) – A potent psychedelic that dramatically alters perception and cognition at microgram doses.
Marijuana (Cannabis, Weed, Pot) – The most widely used illicit drug, containing psychoactive cannabinoids THC only.
MDA (Sass, Love Drug, 3,4‑methylenedioxyamphetamine) – An entactogenic and psychedelic stimulant similar to MDMA but with stronger visuals.
MDMA (Ecstasy, Molly, 3,4‑methylenedioxymethamphetamine) – A popular club drug producing euphoria, empathy, and heightened sensory perception.
MDMB‑4en‑PINACA butanoic acid () – A primary metabolite confirming use of the potent synthetic cannabinoid MDMB‑4en‑PINACA.
Meperidine (Demerol, Pethidine) – A synthetic opioid analgesic now rarely used due to its toxic metabolite normeperidine.
Meprobamate (Miltown, Equanil) – A historical anxiolytic “tranquilizer” that produces barbiturate‑like sedation and dependency risk.
Methadone (Dolophine, Methadose, Done) – A long‑acting opioid agonist employed in maintenance therapy and chronic pain management.
Methamphetamine (Crystal Meth, Ice, Desoxyn) – A powerful stimulant drug with high addiction potential and neurotoxic effects when abused.
Metonitazene () – A nitazene‑class synthetic opioid comparable in potency to fentanyl and implicated in recent overdose clusters.
Mitragynine () – The main kratom alkaloid acting as a partial opioid receptor agonist with stimulant properties at low doses.
Morphine (MS Contin, Miss Emma, Morph) – The prototypical opioid analgesic used for severe pain but prone to tolerance and dependence.
N,N‑Dimethylpentylone () – A novel synthetic cathinone stimulant (“bath salt”) producing amphetamine‑like sympathomimetic effects.
Naltrexone (Vivitrol, Revia) – An opioid antagonist medication that blocks opioid and alcohol effects to support abstinence.
N‑Desethylmetonitazene () – A potent nitazene opioid analog/metabolite contributing to toxicity in illicit opioid samples.
Norbuprenorphine () – The primary active metabolite of buprenorphine with limited brain penetration and peripheral opioid effects.
Norcarfentanil () – The main metabolite of carfentanil detected in biological samples after exposure to the parent ultra‑potent opioid.
Nordiazepam (Desmethyldiazepam, Nordazepam) – A long‑acting active metabolite of diazepam that extends benzodiazepine sedation.
Norfentanyl () – The principal inactive metabolite of fentanyl used as a biomarker of fentanyl intake.
Norketamine () – The chief metabolite of ketamine that retains mild anesthetic and analgesic activity.
Normeperidine (Norpethidine) – A neurotoxic excitatory metabolite of meperidine that can cause seizures at high concentrations.
Noroxycodone () – An inactive N‑demethylated metabolite of oxycodone excreted renally.
N‑Pyrrolidinoetonitazene () – An emerging nitazene synthetic opioid of extreme potency implicated in fatal overdoses.
O‑Desmethyltramadol (O‑DSMT) – The active metabolite of tramadol with significantly stronger μ‑opioid receptor activity than the parent drug.
ortho‑Methylfentanyl (2‑Methylfentanyl) – A highly potent clandestine fentanyl analog historically known as “China White.”
Oxazepam (Serax) – A short‑to‑intermediate‑acting benzodiazepine used for anxiety and alcohol withdrawal.
Oxycodone (OxyContin, Percocet, Hillbilly Heroin) – A semi‑synthetic opioid widely prescribed for pain and heavily misused for its heroin‑like high.
Oxymorphone (Opana) – A very potent opioid analgesic withdrawn from U.S. markets due to abuse of its extended‑release form.
para‑Fluorofentanyl (p‑Fluorofentanyl) – A fentanyl analog with comparable potency that has surfaced in illicit opioid mixtures.
para‑Fluoronorfentanyl () – The N‑dealkylated metabolite of para‑fluorofentanyl used to confirm exposure to the parent analog.
Pentylone (bk‑MBDP, βk‑Methylbenzodioxylpentanamine) – A synthetic cathinone stimulant producing euphoria and increased energy similar to methylone.
Phencyclidine (PCP, Angel Dust, Sherm) – A dissociative anesthetic that causes hallucinations, detachment, and unpredictable behavior.
Pregabalin (Lyrica) – An anticonvulsant and anxiolytic agent used for neuropathic pain and prone to misuse for its calming effects.
Psilocin (4‑HO‑DMT) – The psychoactive metabolite of psilocybin responsible for the hallucinations of “magic mushrooms.”
Psilocybin (4‑PO‑DMT) – A natural prodrug compound in psychedelic mushrooms that converts to psilocin to produce its effects.
R‑HHC‑COOH () – The carboxylic acid metabolite of the R‑enantiomer of hexahydrocannabinol excreted after HHC use.
S‑HHC‑COOH () – The carboxylic acid metabolite of the S‑enantiomer of hexahydrocannabinol excreted after HHC use.
Speciociliatine () – A minor kratom alkaloid with weak opioid activity contributing modestly to the plant’s overall effects.
Temazepam (Restoril, Jellies) – A benzodiazepine hypnotic taken for short‑term insomnia and sometimes abused for its strong sedation.
Xylazine (Tranq, Rompun) – A veterinary sedative increasingly found as a street‑drug adulterant causing deep sedation and severe skin ulcers.
Zolpidem (Ambien, Stilnox) – A short‑acting non‑benzodiazepine hypnotic prescribed for insomnia that can cause complex sleep behaviors.
Zopiclone (Imovane) – A non‑benzodiazepine sleep aid used to treat insomnia, known for metallic after‑taste and next‑day drowsiness.

### Example #1 
Post: I got her hooked on that lean everyday she say she want codeine
[{"index_term": "Codeine", "matched_phrase": "lean"}, {"index_term": "Codeine", "matched_phrase": "codeine"}]

### Example #2 
Post: Pulled an all‑nighter on addy again.
[{"index_term": "Amphetamine", "matched_phrase": "addy"}]

### Example #3
Post: Popped two xans before class.
[{"index_term": "other", "matched_phrase": "xans"}]

### Example #4 (Cocaine not on the list)
Post: Picked up fresh snow to ride those white lines tonight ❄️
[{"index_term": "other", "matched_phrase": "snow"}, {"index_term": "other", "matched_phrase": "white lines"}]

Post: {{tweet_text}}
"""

# %% [markdown]
# # RUN 4 MODELS: long_prompt

# %%
# o4-mini (smarter than GPT-4o-mini)
responses = run_prompt_on_llm(get_openai_o4mini_response, "o4mini_entity_linking", entity_linking_prompt, tweets)

# GPT-4o-mini
responses = run_prompt_on_llm(get_openai_gpt4omini_response, "gpt4omini_entity_linking", entity_linking_prompt, tweets)

# # Meta-Llama-3.1-8B-Instruct
# responses = run_prompt_on_llm(get_llama_response, "llama_entity_linking", entity_linking_prompt, tweets)
# cleanup_llama()

# # Qwen-4B
# responses = run_prompt_on_llm(get_qwen_4b_response, "qwen_4b_entity_linking", entity_linking_prompt, tweets)
# cleanup_qwen_4b()
# Out:
# 100%|██████████| 1000/1000 [1:36:59<00:00,  5.82s/it]
# 100%|██████████| 1000/1000 [18:45<00:00,  1.13s/it]

# %%
# Collect responses from saved files, get labels and explanations
responses = extract_responses(tweets, "gpt4omini_entity_linking")
tweets["4o_mini_response_entity_linking"] = responses
drug_labels = extract_drug_labels(tweets, "gpt4omini_entity_linking")
tweets["4o_mini_drug_labels"] = drug_labels

responses = extract_responses(tweets, "o4mini_entity_linking")
tweets["o4mini_response_entity_linking"] = responses   
drug_labels = extract_drug_labels(tweets, "o4mini_entity_linking")
tweets["o4mini_drug_labels"] = drug_labels

# responses = extract_responses(tweets, "qwen_4b_entity_linking")
# tweets["qwen_4b_response_entity_linking"] = responses
# drug_labels = extract_drug_labels(tweets, "qwen_4b_entity_linking")
# tweets["qwen_4b_drug_labels"] = drug_labels

responses = extract_responses(tweets, "llama_entity_linking")
tweets["llama_response_entity_linking"] = responses
drug_labels = extract_drug_labels(tweets, "llama_entity_linking")
tweets["llama_drug_labels"] = drug_labels

tweets.info(verbose=True)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 15820.76it/s]
# Extracting labels: 100%|██████████| 1000/1000 [00:00<00:00, 13474.42it/s]
# Error: No JSON found in 'gpt4omini_entity_linking/1   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/2   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/3   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/6   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/7   []'
# Error: No JSON found in 'gpt4omini_entity_linking/9   []'
# Error: No JSON found in 'gpt4omini_entity_linking/10   []'
# Error: No JSON found in 'gpt4omini_entity_linking/12   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/16   []'
# Error: No JSON found in 'gpt4omini_entity_linking/19   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/20   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/23   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/24   []'
# Error: No JSON found in 'gpt4omini_entity_linking/25   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/26   []'
# Error: No JSON found in 'gpt4omini_entity_linking/28   []'
# Error: No JSON found in 'gpt4omini_entity_linking/30   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/31   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/34   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/36   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/37   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/43   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/46   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/48   []'
# Error: No JSON found in 'gpt4omini_entity_linking/49   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/50   []'
# Error: No JSON found in 'gpt4omini_entity_linking/53   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/56   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/57   []'
# Error: No JSON found in 'gpt4omini_entity_linking/58   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/60   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/61   []'
# Error: No JSON found in 'gpt4omini_entity_linking/67   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/70   []'
# Error: No JSON found in 'gpt4omini_entity_linking/72   []'
# Error: No JSON found in 'gpt4omini_entity_linking/74   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/75   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/76   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/78   []'
# Error: No JSON found in 'gpt4omini_entity_linking/79   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/81   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/82   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/84   []'
# Error: No JSON found in 'gpt4omini_entity_linking/86   []'
# Error: No JSON found in 'gpt4omini_entity_linking/87   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/90   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/91   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/92   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/93   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/94   []'
# Error: No JSON found in 'gpt4omini_entity_linking/95   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/96   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/98   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/99   []'
# Error: No JSON found in 'gpt4omini_entity_linking/101   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/104   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/106   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/108   []'
# Error: No JSON found in 'gpt4omini_entity_linking/110   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/112   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/113   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/115   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/118   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/119   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/121   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/125   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/126   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/127   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/132   []'
# Error: No JSON found in 'gpt4omini_entity_linking/135   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/137   []'
# Error: No JSON found in 'gpt4omini_entity_linking/138   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/142   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/143   []'
# Error: No JSON found in 'gpt4omini_entity_linking/144   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/146   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/147   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/148   []'
# Error: No JSON found in 'gpt4omini_entity_linking/149   []'
# Error: No JSON found in 'gpt4omini_entity_linking/151   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/152   []'
# Error: No JSON found in 'gpt4omini_entity_linking/154   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/156   []'
# Error: No JSON found in 'gpt4omini_entity_linking/158   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/163   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/164   []'
# Error: No JSON found in 'gpt4omini_entity_linking/166   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/169   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/171   []'
# Error: No JSON found in 'gpt4omini_entity_linking/172   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/173   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/178   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/179   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/180   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/182   []'
# Error: No JSON found in 'gpt4omini_entity_linking/184   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/189   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/190   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/192   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/193   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/195   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/197   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/200   []'
# Error: No JSON found in 'gpt4omini_entity_linking/201   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/204   []'
# Error: No JSON found in 'gpt4omini_entity_linking/208   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/209   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/210   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/211   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/214   []'
# Error: No JSON found in 'gpt4omini_entity_linking/215   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/216   []'
# Error: No JSON found in 'gpt4omini_entity_linking/220   []'
# Error: No JSON found in 'gpt4omini_entity_linking/221   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/223   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/224   []'
# Error: No JSON found in 'gpt4omini_entity_linking/231   []'
# Error: No JSON found in 'gpt4omini_entity_linking/233   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/239   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/240   []'
# Error: No JSON found in 'gpt4omini_entity_linking/246   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/247   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/248   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/249   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/250   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/256   []'
# Error: No JSON found in 'gpt4omini_entity_linking/260   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/263   []'
# Error: No JSON found in 'gpt4omini_entity_linking/265   []'
# Error: No JSON found in 'gpt4omini_entity_linking/268   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/269   []'
# Error: No JSON found in 'gpt4omini_entity_linking/270   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/271   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/274   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/279   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/280   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/282   []'
# Error: No JSON found in 'gpt4omini_entity_linking/283   []'
# Error: No JSON found in 'gpt4omini_entity_linking/284   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/287   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/291   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/292   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/296   []'
# Error: No JSON found in 'gpt4omini_entity_linking/299   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/301   []'
# Error: No JSON found in 'gpt4omini_entity_linking/303   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/304   []'
# Error: No JSON found in 'gpt4omini_entity_linking/306   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/307   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/308   []'
# Error: No JSON found in 'gpt4omini_entity_linking/313   []'
# Error: No JSON found in 'gpt4omini_entity_linking/316   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/325   []'
# Error: No JSON found in 'gpt4omini_entity_linking/326   []'
# Error: No JSON found in 'gpt4omini_entity_linking/328   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/332   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/333   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/335   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/337   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/338   []'
# Error: No JSON found in 'gpt4omini_entity_linking/339   []'
# Error: No JSON found in 'gpt4omini_entity_linking/341   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/342   []'
# Error: No JSON found in 'gpt4omini_entity_linking/343   []'
# Error: No JSON found in 'gpt4omini_entity_linking/344   []'
# Error: No JSON found in 'gpt4omini_entity_linking/345   []'
# Error: No JSON found in 'gpt4omini_entity_linking/346   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/347   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/348   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/349   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/354   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/356   []'
# Error: No JSON found in 'gpt4omini_entity_linking/357   []'
# Error: No JSON found in 'gpt4omini_entity_linking/363   []'
# Error: No JSON found in 'gpt4omini_entity_linking/364   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/366   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/367   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/368   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/371   []'
# Error: No JSON found in 'gpt4omini_entity_linking/374   []'
# Error: No JSON found in 'gpt4omini_entity_linking/375   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/376   []'
# Error: No JSON found in 'gpt4omini_entity_linking/379   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/380   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/381   []'
# Error: No JSON found in 'gpt4omini_entity_linking/383   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/389   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/390   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/391   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/393   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/395   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/399   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/401   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/402   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/404   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/407   []'
# Error: No JSON found in 'gpt4omini_entity_linking/408   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/410   []'
# Error: No JSON found in 'gpt4omini_entity_linking/414   []'
# Error: No JSON found in 'gpt4omini_entity_linking/417   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/418   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/421   []'
# Error: No JSON found in 'gpt4omini_entity_linking/422   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/423   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/424   []'
# Error: No JSON found in 'gpt4omini_entity_linking/425   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/426   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/429   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/432   []'
# Error: No JSON found in 'gpt4omini_entity_linking/433   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/434   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/437   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/438   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/439   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/442   []'
# Error: No JSON found in 'gpt4omini_entity_linking/443   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/445   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/447   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/449   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/451   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/452   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/453   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/454   []'
# Error: No JSON found in 'gpt4omini_entity_linking/455   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/460   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/463   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/464   []'
# Error: No JSON found in 'gpt4omini_entity_linking/465   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/467   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/470   []'
# Error: No JSON found in 'gpt4omini_entity_linking/473   []'
# Error: No JSON found in 'gpt4omini_entity_linking/474   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/475   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/479   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/482   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/484   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/485   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/487   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/488   []'
# Error: No JSON found in 'gpt4omini_entity_linking/489   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/490   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/493   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/494   []'
# Error: No JSON found in 'gpt4omini_entity_linking/497   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/498   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/502   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/503   []'
# Error: No JSON found in 'gpt4omini_entity_linking/506   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/509   []'
# Error: No JSON found in 'gpt4omini_entity_linking/511   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/515   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/517   []'
# Error: No JSON found in 'gpt4omini_entity_linking/519   []'
# Error: No JSON found in 'gpt4omini_entity_linking/520   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/521   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/523   []'
# Error: No JSON found in 'gpt4omini_entity_linking/524   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/526   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/527   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/528   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/529   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/532   []'
# Error: No JSON found in 'gpt4omini_entity_linking/536   []'
# Error: No JSON found in 'gpt4omini_entity_linking/542   []'
# Error: No JSON found in 'gpt4omini_entity_linking/544   []'
# Error: No JSON found in 'gpt4omini_entity_linking/546   []'
# Error: No JSON found in 'gpt4omini_entity_linking/548   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/551   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/552   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/554   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/558   []'
# Error: No JSON found in 'gpt4omini_entity_linking/559   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/563   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/564   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/565   []'
# Error: No JSON found in 'gpt4omini_entity_linking/566   []'
# Error: No JSON found in 'gpt4omini_entity_linking/567   []'
# Error: No JSON found in 'gpt4omini_entity_linking/569   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/572   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/573   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/576   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/583   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/584   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/586   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/588   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/591   []'
# Error: No JSON found in 'gpt4omini_entity_linking/592   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/594   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/596   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/597   []'
# Error: No JSON found in 'gpt4omini_entity_linking/603   []'
# Error: No JSON found in 'gpt4omini_entity_linking/607   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/609   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/611   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/612   []'
# Error: No JSON found in 'gpt4omini_entity_linking/613   []'
# Error: No JSON found in 'gpt4omini_entity_linking/614   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/615   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/616   []'
# Error: No JSON found in 'gpt4omini_entity_linking/619   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/621   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/623   []'
# Error: No JSON found in 'gpt4omini_entity_linking/626   []'
# Error: No JSON found in 'gpt4omini_entity_linking/627   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/630   []'
# Error: No JSON found in 'gpt4omini_entity_linking/635   []'
# Error: No JSON found in 'gpt4omini_entity_linking/636   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/642   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/648   []'
# Error: No JSON found in 'gpt4omini_entity_linking/649   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/651   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/654   []'
# Error: No JSON found in 'gpt4omini_entity_linking/655   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/656   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/657   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/659   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/660   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/663   []'
# Error: No JSON found in 'gpt4omini_entity_linking/664   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/665   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/666   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/669   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/670   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/672   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/674   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/675   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/677   []'
# Error: No JSON found in 'gpt4omini_entity_linking/678   []'
# Error: No JSON found in 'gpt4omini_entity_linking/679   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/682   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/687   []'
# Error: No JSON found in 'gpt4omini_entity_linking/688   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/689   []'
# Error: No JSON found in 'gpt4omini_entity_linking/694   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/696   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/697   []'
# Error: No JSON found in 'gpt4omini_entity_linking/698   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/705   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/712   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/713   []'
# Error: No JSON found in 'gpt4omini_entity_linking/715   []'
# Error: No JSON found in 'gpt4omini_entity_linking/718   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/721   []'
# Error: No JSON found in 'gpt4omini_entity_linking/722   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/725   []'
# Error: No JSON found in 'gpt4omini_entity_linking/727   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/728   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/729   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/730   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/731   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/733   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/734   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/739   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/740   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/741   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/742   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/745   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/748   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/749   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/750   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/755   []'
# Error: No JSON found in 'gpt4omini_entity_linking/756   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/759   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/761   []'
# Error: No JSON found in 'gpt4omini_entity_linking/762   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/765   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/767   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/768   []'
# Error: No JSON found in 'gpt4omini_entity_linking/772   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/773   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/774   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/776   []'
# Error: No JSON found in 'gpt4omini_entity_linking/777   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/779   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/781   []'
# Error: No JSON found in 'gpt4omini_entity_linking/783   []'
# Error: No JSON found in 'gpt4omini_entity_linking/784   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/785   []'
# Error: No JSON found in 'gpt4omini_entity_linking/786   []'
# Error: No JSON found in 'gpt4omini_entity_linking/787   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/788   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/789   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/790   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/792   []'
# Error: No JSON found in 'gpt4omini_entity_linking/794   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/795   []'
# Error: No JSON found in 'gpt4omini_entity_linking/798   []'
# Error: No JSON found in 'gpt4omini_entity_linking/800   []'
# Error: No JSON found in 'gpt4omini_entity_linking/802   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/824   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/825   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/827   []'
# Error: No JSON found in 'gpt4omini_entity_linking/828   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/830   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/831   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/832   []'
# Error: No JSON found in 'gpt4omini_entity_linking/837   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/840   []'
# Error: No JSON found in 'gpt4omini_entity_linking/842   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/846   []'
# Error: No JSON found in 'gpt4omini_entity_linking/847   []'
# Error: No JSON found in 'gpt4omini_entity_linking/849   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/850   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/851   []'
# Error: No JSON found in 'gpt4omini_entity_linking/852   []'
# Error: No JSON found in 'gpt4omini_entity_linking/853   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/854   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/855   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/856   []'
# Error: No JSON found in 'gpt4omini_entity_linking/857   []'
# Error: No JSON found in 'gpt4omini_entity_linking/858   []'
# Error: No JSON found in 'gpt4omini_entity_linking/859   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/860   []'
# Error: No JSON found in 'gpt4omini_entity_linking/861   []'
# Error: No JSON found in 'gpt4omini_entity_linking/862   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/863   []'
# Error: No JSON found in 'gpt4omini_entity_linking/864   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/865   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/866   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/867   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/868   []'
# Error: No JSON found in 'gpt4omini_entity_linking/869   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/870   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/871   []'
# Error: No JSON found in 'gpt4omini_entity_linking/872   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/874   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/875   []'
# Error: No JSON found in 'gpt4omini_entity_linking/876   []'
# Error: No JSON found in 'gpt4omini_entity_linking/877   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/878   []'
# Error: No JSON found in 'gpt4omini_entity_linking/879   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/880   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/883   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/884   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/885   []'
# Error: No JSON found in 'gpt4omini_entity_linking/886   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/889   []'
# Error: No JSON found in 'gpt4omini_entity_linking/891   []'
# Error: No JSON found in 'gpt4omini_entity_linking/892   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/893   []'
# Error: No JSON found in 'gpt4omini_entity_linking/895   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/897   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/898   []'
# Error: No JSON found in 'gpt4omini_entity_linking/899   []'
# Error: No JSON found in 'gpt4omini_entity_linking/900   []'
# Error: No JSON found in 'gpt4omini_entity_linking/901   []'
# Error: No JSON found in 'gpt4omini_entity_linking/907   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/910   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/912   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/915   []'
# Error: No JSON found in 'gpt4omini_entity_linking/916   []'
# Error: No JSON found in 'gpt4omini_entity_linking/917   []'
# Error: No JSON found in 'gpt4omini_entity_linking/920   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/921   []'
# Error: No JSON found in 'gpt4omini_entity_linking/922   []'
# Error: No JSON found in 'gpt4omini_entity_linking/924   []'
# Error: No JSON found in 'gpt4omini_entity_linking/926   []'
# Error: No JSON found in 'gpt4omini_entity_linking/930   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/931   []'
# Error: No JSON found in 'gpt4omini_entity_linking/934   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/938   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/946   []'
# Error: No JSON found in 'gpt4omini_entity_linking/948   []'
# Error: No JSON found in 'gpt4omini_entity_linking/951   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/952   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/953   []'
# Error: No JSON found in 'gpt4omini_entity_linking/955   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/956   []'
# Error: No JSON found in 'gpt4omini_entity_linking/957   []'
# Error: No JSON found in 'gpt4omini_entity_linking/959   []'
# Error: No JSON found in 'gpt4omini_entity_linking/961   []'
# Error: No JSON found in 'gpt4omini_entity_linking/962   []'
# Error: No JSON found in 'gpt4omini_entity_linking/963   []'
# Error: No JSON found in 'gpt4omini_entity_linking/978   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/990   []'
# Error: No JSON found in 'gpt4omini_entity_linking/993   ```json
# []
# ```'
# Error: No JSON found in 'gpt4omini_entity_linking/997   ```json
# []
# ```'
# 100%|██████████| 1000/1000 [00:00<00:00, 14786.64it/s]
# Extracting labels:   0%|          | 0/1000 [00:00<?, ?it/s]
# Error: No JSON found in 'o4mini_entity_linking/6   []'
# Error: No JSON found in 'o4mini_entity_linking/7   []'
# Error: No JSON found in 'o4mini_entity_linking/8   []'
# Error: No JSON found in 'o4mini_entity_linking/9   []'
# Error: No JSON found in 'o4mini_entity_linking/10   []'
# Error: No JSON found in 'o4mini_entity_linking/12   []'
# Error: No JSON found in 'o4mini_entity_linking/16   []'
# Error: No JSON found in 'o4mini_entity_linking/19   []'
# Error: No JSON found in 'o4mini_entity_linking/20   []'
# Error: No JSON found in 'o4mini_entity_linking/24   []'
# Error: No JSON found in 'o4mini_entity_linking/26   []'
# Error: No JSON found in 'o4mini_entity_linking/28   []'
# Error: No JSON found in 'o4mini_entity_linking/48   []'
# Error: No JSON found in 'o4mini_entity_linking/51   []'
# Error: No JSON found in 'o4mini_entity_linking/53   []'
# Error: No JSON found in 'o4mini_entity_linking/57   []'
# Error: No JSON found in 'o4mini_entity_linking/61   []'
# Error: No JSON found in 'o4mini_entity_linking/63   []'
# Error: No JSON found in 'o4mini_entity_linking/70   []'
# Error: No JSON found in 'o4mini_entity_linking/72   []'
# Error: No JSON found in 'o4mini_entity_linking/75   []'
# Error: No JSON found in 'o4mini_entity_linking/78   []'
# Error: No JSON found in 'o4mini_entity_linking/84   []'
# Error: No JSON found in 'o4mini_entity_linking/86   []'
# Error: No JSON found in 'o4mini_entity_linking/88   []'
# Error: No JSON found in 'o4mini_entity_linking/89   []'
# Error: No JSON found in 'o4mini_entity_linking/90   []'
# Error: No JSON found in 'o4mini_entity_linking/91   []'
# Error: No JSON found in 'o4mini_entity_linking/92   []'
# Error: No JSON found in 'o4mini_entity_linking/94   []'
# Error: No JSON found in 'o4mini_entity_linking/95   []'
# Error: No JSON found in 'o4mini_entity_linking/96   []'
# Error: No JSON found in 'o4mini_entity_linking/99   []'
# Error: No JSON found in 'o4mini_entity_linking/101   []'
# Error: No JSON found in 'o4mini_entity_linking/104   []'
# Error: No JSON found in 'o4mini_entity_linking/106   []'
# Error: No JSON found in 'o4mini_entity_linking/108   []'
# Error: No JSON found in 'o4mini_entity_linking/110   []'
# Error: No JSON found in 'o4mini_entity_linking/112   []'
# Error: No JSON found in 'o4mini_entity_linking/118   []'
# Error: No JSON found in 'o4mini_entity_linking/121   []'
# Error: No JSON found in 'o4mini_entity_linking/126   []'
# Error: No JSON found in 'o4mini_entity_linking/127   []'
# Error: No JSON found in 'o4mini_entity_linking/129   []'
# Error: No JSON found in 'o4mini_entity_linking/132   []'
# Error: No JSON found in 'o4mini_entity_linking/137   []'
# Error: No JSON found in 'o4mini_entity_linking/138   []'
# Error: No JSON found in 'o4mini_entity_linking/143   []'
# Error: No JSON found in 'o4mini_entity_linking/144   []'
# Error: No JSON found in 'o4mini_entity_linking/146   []'
# Error: No JSON found in 'o4mini_entity_linking/149   []'
# Error: No JSON found in 'o4mini_entity_linking/152   []'
# Error: No JSON found in 'o4mini_entity_linking/154   []'
# Error: No JSON found in 'o4mini_entity_linking/156   []'
# Error: No JSON found in 'o4mini_entity_linking/163   []'
# Error: No JSON found in 'o4mini_entity_linking/164   []'
# Error: No JSON found in 'o4mini_entity_linking/169   []'
# Error: No JSON found in 'o4mini_entity_linking/171   []'
# Error: No JSON found in 'o4mini_entity_linking/172   []'
# Error: No JSON found in 'o4mini_entity_linking/173   []'
# Error: No JSON found in 'o4mini_entity_linking/178   []'
# Error: No JSON found in 'o4mini_entity_linking/180   []'
# Error: No JSON found in 'o4mini_entity_linking/182   []'
# Error: No JSON found in 'o4mini_entity_linking/184   []'
# Error: No JSON found in 'o4mini_entity_linking/189   []'
# Error: No JSON found in 'o4mini_entity_linking/195   []'
# Error: No JSON found in 'o4mini_entity_linking/199   []'
# Error: No JSON found in 'o4mini_entity_linking/200   []'
# Error: No JSON found in 'o4mini_entity_linking/201   []'
# Error: No JSON found in 'o4mini_entity_linking/210   []'
# Error: No JSON found in 'o4mini_entity_linking/211   []'
# Error: No JSON found in 'o4mini_entity_linking/216   []'
# Error: No JSON found in 'o4mini_entity_linking/218   []'
# Error: No JSON found in 'o4mini_entity_linking/219   []'
# Error: No JSON found in 'o4mini_entity_linking/220   []'
# Error: No JSON found in 'o4mini_entity_linking/231   []'
# Error: No JSON found in 'o4mini_entity_linking/233   []'
# Error: No JSON found in 'o4mini_entity_linking/239   []'
# Error: No JSON found in 'o4mini_entity_linking/240   []'
# Error: No JSON found in 'o4mini_entity_linking/246   []'
# Error: No JSON found in 'o4mini_entity_linking/256   []'
# Error: No JSON found in 'o4mini_entity_linking/263   []'
# Error: No JSON found in 'o4mini_entity_linking/267   []'
# Error: No JSON found in 'o4mini_entity_linking/269   []'
# Error: No JSON found in 'o4mini_entity_linking/270   []'
# Error: No JSON found in 'o4mini_entity_linking/283   []'
# Error: No JSON found in 'o4mini_entity_linking/287   []'
# Error: No JSON found in 'o4mini_entity_linking/291   []'
# Error: No JSON found in 'o4mini_entity_linking/296   []'
# Error: No JSON found in 'o4mini_entity_linking/301   []'
# Error: No JSON found in 'o4mini_entity_linking/304   []'
# Error: No JSON found in 'o4mini_entity_linking/306   []'
# Error: No JSON found in 'o4mini_entity_linking/313   []'
# Error: No JSON found in 'o4mini_entity_linking/325   []'
# Error: No JSON found in 'o4mini_entity_linking/326   []'
# Error: No JSON found in 'o4mini_entity_linking/328   []'
# Error: No JSON found in 'o4mini_entity_linking/329   []'
# Error: No JSON found in 'o4mini_entity_linking/332   []'
# Error: No JSON found in 'o4mini_entity_linking/337   []'
# Error: No JSON found in 'o4mini_entity_linking/338   []'
# Error: No JSON found in 'o4mini_entity_linking/339   []'
# Error: No JSON found in 'o4mini_entity_linking/341   []'
# Error: No JSON found in 'o4mini_entity_linking/342   []'
# Error: No JSON found in 'o4mini_entity_linking/344   []'
# Error: No JSON found in 'o4mini_entity_linking/345   []'
# Error: No JSON found in 'o4mini_entity_linking/347   []'
# Error: No JSON found in 'o4mini_entity_linking/348   []'
# Error: No JSON found in 'o4mini_entity_linking/354   []'
# Error: No JSON found in 'o4mini_entity_linking/356   []'
# Error: No JSON found in 'o4mini_entity_linking/357   []'
# Error: No JSON found in 'o4mini_entity_linking/363   []'
# Error: No JSON found in 'o4mini_entity_linking/367   []'
# Error: No JSON found in 'o4mini_entity_linking/368   []'
# Error: No JSON found in 'o4mini_entity_linking/371   []'
# Error: No JSON found in 'o4mini_entity_linking/374   []'
# Error: No JSON found in 'o4mini_entity_linking/376   []'
# Error: No JSON found in 'o4mini_entity_linking/381   []'
# Error: No JSON found in 'o4mini_entity_linking/383   []'
# Error: No JSON found in 'o4mini_entity_linking/389   []'
# Error: No JSON found in 'o4mini_entity_linking/395   []'
# Error: No JSON found in 'o4mini_entity_linking/399   []'
# Error: No JSON found in 'o4mini_entity_linking/401   []'
# Error: No JSON found in 'o4mini_entity_linking/402   []'
# Error: No JSON found in 'o4mini_entity_linking/404   []'
# Error: No JSON found in 'o4mini_entity_linking/410   []'
# Error: No JSON found in 'o4mini_entity_linking/414   []'
# Error: No JSON found in 'o4mini_entity_linking/417   []'
# Error: No JSON found in 'o4mini_entity_linking/421   []'
# Error: No JSON found in 'o4mini_entity_linking/422   []'
# Error: No JSON found in 'o4mini_entity_linking/423   []'
# Error: No JSON found in 'o4mini_entity_linking/424   []'
# Error: No JSON found in 'o4mini_entity_linking/425   []'
# Error: No JSON found in 'o4mini_entity_linking/429   []'
# Error: No JSON found in 'o4mini_entity_linking/432   []'
# Error: No JSON found in 'o4mini_entity_linking/439   []'
# Error: No JSON found in 'o4mini_entity_linking/442   []'
# Error: No JSON found in 'o4mini_entity_linking/443   []'
# Error: No JSON found in 'o4mini_entity_linking/445   []'
# Error: No JSON found in 'o4mini_entity_linking/447   []'
# Error: No JSON found in 'o4mini_entity_linking/449   []'
# Error: No JSON found in 'o4mini_entity_linking/451   []'
# Error: No JSON found in 'o4mini_entity_linking/452   []'
# Error: No JSON found in 'o4mini_entity_linking/454   []'
# Error: No JSON found in 'o4mini_entity_linking/457   []'
# Error: No JSON found in 'o4mini_entity_linking/458   []'
# Error: No JSON found in 'o4mini_entity_linking/463   []'
# Error: No JSON found in 'o4mini_entity_linking/464   []'
# Error: No JSON found in 'o4mini_entity_linking/467   []'
# Error: No JSON found in 'o4mini_entity_linking/470   []'
# Error: No JSON found in 'o4mini_entity_linking/473   []'
# Error: No JSON found in 'o4mini_entity_linking/474   []'
# Error: No JSON found in 'o4mini_entity_linking/475   []'
# Error: No JSON found in 'o4mini_entity_linking/481   []'
# Error: No JSON found in 'o4mini_entity_linking/482   []'
# Error: No JSON found in 'o4mini_entity_linking/488   []'
# Error: No JSON found in 'o4mini_entity_linking/490   []'
# Error: No JSON found in 'o4mini_entity_linking/493   []'
# Error: No JSON found in 'o4mini_entity_linking/498   []'
# Error: No JSON found in 'o4mini_entity_linking/499   []'
# Error: No JSON found in 'o4mini_entity_linking/502   []'
# Error: No JSON found in 'o4mini_entity_linking/503   []'
# Error: No JSON found in 'o4mini_entity_linking/506   []'
# Error: No JSON found in 'o4mini_entity_linking/515   []'
# Error: No JSON found in 'o4mini_entity_linking/517   []'
# Error: No JSON found in 'o4mini_entity_linking/519   []'
# Error: No JSON found in 'o4mini_entity_linking/520   []'
# Error: No JSON found in 'o4mini_entity_linking/521   []'
# Error: No JSON found in 'o4mini_entity_linking/523   []'
# Error: No JSON found in 'o4mini_entity_linking/524   []'
# Error: No JSON found in 'o4mini_entity_linking/527   []'
# Error: No JSON found in 'o4mini_entity_linking/528   []'
# Error: No JSON found in 'o4mini_entity_linking/529   []'
# Error: No JSON found in 'o4mini_entity_linking/532   []'
# Error: No JSON found in 'o4mini_entity_linking/533   []'
# Error: No JSON found in 'o4mini_entity_linking/542   []'
# Error: No JSON found in 'o4mini_entity_linking/544   []'
# Error: No JSON found in 'o4mini_entity_linking/546   []'
# Error: No JSON found in 'o4mini_entity_linking/554   []'
# Error: No JSON found in 'o4mini_entity_linking/558   []'
# Error: No JSON found in 'o4mini_entity_linking/559   []'
# Error: No JSON found in 'o4mini_entity_linking/563   []'
# Error: No JSON found in 'o4mini_entity_linking/565   []'
# Error: No JSON found in 'o4mini_entity_linking/566   []'
# Error: No JSON found in 'o4mini_entity_linking/572   []'
# Error: No JSON found in 'o4mini_entity_linking/583   []'
# Error: No JSON found in 'o4mini_entity_linking/584   []'
# Error: No JSON found in 'o4mini_entity_linking/586   []'
# Error: No JSON found in 'o4mini_entity_linking/591   []'
# Error: No JSON found in 'o4mini_entity_linking/600   []'
# Error: No JSON found in 'o4mini_entity_linking/603   []'
# Error: No JSON found in 'o4mini_entity_linking/607   []'
# Error: No JSON found in 'o4mini_entity_linking/609   []'
# Error: No JSON found in 'o4mini_entity_linking/613   []'
# Error: No JSON found in 'o4mini_entity_linking/614   []'
# Error: No JSON found in 'o4mini_entity_linking/615   []'
# Error: No JSON found in 'o4mini_entity_linking/616   []'
# Error: No JSON found in 'o4mini_entity_linking/619   []'
# Error: No JSON found in 'o4mini_entity_linking/621   []'
# Error: No JSON found in 'o4mini_entity_linking/622   []'
# Error: No JSON found in 'o4mini_entity_linking/623   []'
# Error: No JSON found in 'o4mini_entity_linking/627   []'
# Error: No JSON found in 'o4mini_entity_linking/635   []'
# Error: No JSON found in 'o4mini_entity_linking/642   []'
# Error: No JSON found in 'o4mini_entity_linking/648   []'
# Error: No JSON found in 'o4mini_entity_linking/649   []'
# Error: No JSON found in 'o4mini_entity_linking/651   []'
# Error: No JSON found in 'o4mini_entity_linking/658   []'
# Error: No JSON found in 'o4mini_entity_linking/664   []'
# Error: No JSON found in 'o4mini_entity_linking/665   []'
# Error: No JSON found in 'o4mini_entity_linking/666   []'
# Error: No JSON found in 'o4mini_entity_linking/669   []'
# Error: No JSON found in 'o4mini_entity_linking/670   []'
# Error: No JSON found in 'o4mini_entity_linking/672   []'
# Error: No JSON found in 'o4mini_entity_linking/673   []'
# Error: No JSON found in 'o4mini_entity_linking/674   []'
# Error: No JSON found in 'o4mini_entity_linking/675   []'
# Error: No JSON found in 'o4mini_entity_linking/677   []'
# Error: No JSON found in 'o4mini_entity_linking/679   []'
# Error: No JSON found in 'o4mini_entity_linking/687   []'
# Error: No JSON found in 'o4mini_entity_linking/689   []'
# Error: No JSON found in 'o4mini_entity_linking/694   []'
# Error: No JSON found in 'o4mini_entity_linking/700   []'
# Error: No JSON found in 'o4mini_entity_linking/705   []'
# Error: No JSON found in 'o4mini_entity_linking/709   []'
# Error: No JSON found in 'o4mini_entity_linking/712   []'
# Error: No JSON found in 'o4mini_entity_linking/713   []'
# Error: No JSON found in 'o4mini_entity_linking/718   []'
# Error: No JSON found in 'o4mini_entity_linking/721   []'
# Error: No JSON found in 'o4mini_entity_linking/729   []'
# Error: No JSON found in 'o4mini_entity_linking/730   []'
# Error: No JSON found in 'o4mini_entity_linking/733   []'
# Error: No JSON found in 'o4mini_entity_linking/734   []'
# Error: No JSON found in 'o4mini_entity_linking/739   []'
# Error: No JSON found in 'o4mini_entity_linking/740   []'
# Error: No JSON found in 'o4mini_entity_linking/742   []'
# Error: No JSON found in 'o4mini_entity_linking/748   []'
# Error: No JSON found in 'o4mini_entity_linking/749   []'
# Error: No JSON found in 'o4mini_entity_linking/750   []'
# Extracting labels: 100%|██████████| 1000/1000 [00:00<00:00, 13229.32it/s]
# Error: No JSON found in 'o4mini_entity_linking/761   []'
# Error: No JSON found in 'o4mini_entity_linking/762   []'
# Error: No JSON found in 'o4mini_entity_linking/768   []'
# Error: No JSON found in 'o4mini_entity_linking/774   []'
# Error: No JSON found in 'o4mini_entity_linking/776   []'
# Error: No JSON found in 'o4mini_entity_linking/777   []'
# Error: No JSON found in 'o4mini_entity_linking/781   []'
# Error: No JSON found in 'o4mini_entity_linking/783   []'
# Error: No JSON found in 'o4mini_entity_linking/784   []'
# Error: No JSON found in 'o4mini_entity_linking/785   []'
# Error: No JSON found in 'o4mini_entity_linking/787   []'
# Error: No JSON found in 'o4mini_entity_linking/792   []'
# Error: No JSON found in 'o4mini_entity_linking/794   []'
# Error: No JSON found in 'o4mini_entity_linking/795   []'
# Error: No JSON found in 'o4mini_entity_linking/798   []'
# Error: No JSON found in 'o4mini_entity_linking/800   []'
# Error: No JSON found in 'o4mini_entity_linking/802   []'
# Error: No JSON found in 'o4mini_entity_linking/827   []'
# Error: No JSON found in 'o4mini_entity_linking/840   []'
# Error: No JSON found in 'o4mini_entity_linking/846   []'
# Error: No JSON found in 'o4mini_entity_linking/847   []'
# Error: No JSON found in 'o4mini_entity_linking/848   []'
# Error: No JSON found in 'o4mini_entity_linking/851   []'
# Error: No JSON found in 'o4mini_entity_linking/852   []'
# Error: No JSON found in 'o4mini_entity_linking/853   []'
# Error: No JSON found in 'o4mini_entity_linking/854   []'
# Error: No JSON found in 'o4mini_entity_linking/856   []'
# Error: No JSON found in 'o4mini_entity_linking/857   []'
# Error: No JSON found in 'o4mini_entity_linking/858   []'
# Error: No JSON found in 'o4mini_entity_linking/859   []'
# Error: No JSON found in 'o4mini_entity_linking/860   []'
# Error: No JSON found in 'o4mini_entity_linking/861   []'
# Error: No JSON found in 'o4mini_entity_linking/863   []'
# Error: No JSON found in 'o4mini_entity_linking/864   []'
# Error: No JSON found in 'o4mini_entity_linking/865   []'
# Error: No JSON found in 'o4mini_entity_linking/866   []'
# Error: No JSON found in 'o4mini_entity_linking/867   []'
# Error: No JSON found in 'o4mini_entity_linking/868   []'
# Error: No JSON found in 'o4mini_entity_linking/869   []'
# Error: No JSON found in 'o4mini_entity_linking/870   []'
# Error: No JSON found in 'o4mini_entity_linking/871   []'
# Error: No JSON found in 'o4mini_entity_linking/872   []'
# Error: No JSON found in 'o4mini_entity_linking/874   []'
# Error: No JSON found in 'o4mini_entity_linking/875   []'
# Error: No JSON found in 'o4mini_entity_linking/877   []'
# Error: No JSON found in 'o4mini_entity_linking/878   []'
# Error: No JSON found in 'o4mini_entity_linking/879   []'
# Error: No JSON found in 'o4mini_entity_linking/880   []'
# Error: No JSON found in 'o4mini_entity_linking/886   []'
# Error: No JSON found in 'o4mini_entity_linking/887   []'
# Error: No JSON found in 'o4mini_entity_linking/889   []'
# Error: No JSON found in 'o4mini_entity_linking/891   []'
# Error: No JSON found in 'o4mini_entity_linking/892   []'
# Error: No JSON found in 'o4mini_entity_linking/893   []'
# Error: No JSON found in 'o4mini_entity_linking/898   []'
# Error: No JSON found in 'o4mini_entity_linking/899   []'
# Error: No JSON found in 'o4mini_entity_linking/915   []'
# Error: No JSON found in 'o4mini_entity_linking/916   []'
# Error: No JSON found in 'o4mini_entity_linking/917   []'
# Error: No JSON found in 'o4mini_entity_linking/920   []'
# Error: No JSON found in 'o4mini_entity_linking/921   []'
# Error: No JSON found in 'o4mini_entity_linking/922   []'
# Error: No JSON found in 'o4mini_entity_linking/924   []'
# Error: No JSON found in 'o4mini_entity_linking/926   []'
# Error: No JSON found in 'o4mini_entity_linking/931   []'
# Error: No JSON found in 'o4mini_entity_linking/938   []'
# Error: No JSON found in 'o4mini_entity_linking/946   []'
# Error: No JSON found in 'o4mini_entity_linking/948   []'
# Error: No JSON found in 'o4mini_entity_linking/951   []'
# Error: No JSON found in 'o4mini_entity_linking/952   []'
# Error: No JSON found in 'o4mini_entity_linking/953   []'
# Error: No JSON found in 'o4mini_entity_linking/955   []'
# Error: No JSON found in 'o4mini_entity_linking/956   []'
# Error: No JSON found in 'o4mini_entity_linking/957   []'
# Error: No JSON found in 'o4mini_entity_linking/958   []'
# Error: No JSON found in 'o4mini_entity_linking/959   []'
# Error: No JSON found in 'o4mini_entity_linking/961   []'
# Error: No JSON found in 'o4mini_entity_linking/963   []'
# Error: No JSON found in 'o4mini_entity_linking/990   []'
# Error: No JSON found in 'o4mini_entity_linking/993   []'
# Error: No JSON found in 'o4mini_entity_linking/997   []'
# 100%|██████████| 1000/1000 [00:00<00:00, 9476.90it/s]
# Extracting labels:   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
# Print value counts for every label column in tweets
label_cols = [col for col in tweets.columns if "label" in col]
for col in label_cols:
    print(f"\nValue counts for '{col}':")
    print(tweets[col].value_counts(dropna=False))

# %%
# Find rows where not all label columns agree (all True or all False)
label_cols = [col for col in tweets.columns if "label" in col and col != "label"]
def not_all_agree(row):
    vals = [str(row[col]).strip().lower() for col in label_cols]
    # Only consider rows where all values are either 'true' or all 'false'
    return not (all(v == "true" for v in vals) or all(v == "false" for v in vals))

disagreeing_tweets = tweets[tweets.apply(not_all_agree, axis=1)].copy()
print(f"Number of rows where label columns do not all agree: {len(disagreeing_tweets)}")
disagreeing_tweets[label_cols + ["text"]].head()

# %%
tweets.to_csv("data/tweets_with_long_prompt_results.csv", index=False, encoding="utf-8-sig")
disagreeing_tweets.to_csv("data/disagreeing_tweets.csv", index=False, encoding="utf-8-sig")

# %%
:)
